# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
crimes = pd.read_csv("US_Crime_Rates_1960_2014.csv")
crimes.head()
# Out:
#    Year  Population    Total  Violent  Property  Murder  Forcible_Rape  \
# 0  1960   179323175  3384200   288460   3095700    9110          17190
# 1  1961   182992000  3488000   289390   3198600    8740          17220
# 2  1962   185771000  3752200   301510   3450700    8530          17550
# 3  1963   188483000  4109500   316970   3792500    8640          17650
# 4  1964   191141000  4564600   364220   4200400    9360          21420
#
#    Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 0   107840              154320    912100        1855400         328200
# 1   106670              156760    949600        1913000         336000
# 2   110860              164570    994300        2089600         366800
# 3   116470              174210   1086400        2297800         408300
# 4   130390              203050   1213200        2514400         472800

# %%
crimes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Year                55 non-null     int64
#  1   Population          55 non-null     int64
#  2   Total               55 non-null     int64
#  3   Violent             55 non-null     int64
#  4   Property            55 non-null     int64
#  5   Murder              55 non-null     int64
#  6   Forcible_Rape       55 non-null     int64
#  7   Robbery             55 non-null     int64
#  8   Aggravated_assault  55 non-null     int64
#  9   Burglary            55 non-null     int64
#  10  Larceny_Theft       55 non-null     int64
#  11  Vehicle_Theft       55 non-null     int64
# dtypes: int64(12)
# memory usage: 5.3 KB

# %%
crimes.describe()
# Out:
#              Year    Population         Total       Violent      Property  \
# count    55.00000  5.500000e+01  5.500000e+01  5.500000e+01  5.500000e+01
# mean   1987.00000  2.461556e+08  1.060315e+07  1.188806e+06  9.412499e+06
# std      16.02082  4.166216e+07  3.175931e+06  4.597107e+05  2.738512e+06
# min    1960.00000  1.793232e+08  3.384200e+06  2.884600e+05  3.095700e+06
# 25%    1973.50000  2.106215e+08  9.096958e+06  9.253150e+05  8.060014e+06
# 50%    1987.00000  2.422829e+08  1.140151e+07  1.322390e+06  1.018259e+07
# 75%    2000.50000  2.833697e+08  1.308449e+07  1.432762e+06  1.160509e+07
# max    2014.00000  3.188571e+08  1.487290e+07  1.932270e+06  1.296110e+07
#
#              Murder  Forcible_Rape        Robbery  Aggravated_assault  \
# count     55.000000      55.000000      55.000000        5.500000e+01
# mean   17317.236364   72714.800000  416449.890909        6.811818e+05
# std     4267.442664   28278.006893  150506.403782        2.960255e+05
# min     8530.000000   17190.000000  106670.000000        1.543200e+05
# 25%    14819.000000   53400.000000  354911.500000        4.384300e+05
# 50%    17030.000000   84230.000000  423557.000000        7.412910e+05
# 75%    20561.500000   92930.000000  512137.000000        9.002150e+05
# max    24700.000000  109060.000000  687730.000000        1.135610e+06
#
#            Burglary  Larceny_Theft  Vehicle_Theft
# count  5.500000e+01   5.500000e+01   5.500000e+01
# mean   2.424017e+06   5.959947e+06   1.028614e+06
# std    7.259004e+05   1.846401e+06   3.455693e+05
# min    9.121000e+05   1.855400e+06   3.282000e+05
# 25%    2.105336e+06   4.843350e+06   7.896260e+05
# 50%    2.329950e+06   6.591900e+06   1.032200e+06
# 75%    3.073600e+06   7.168450e+06   1.239302e+06
# max    3.795200e+06   8.142200e+06   1.661700e+06

# %%
crimes.value_counts().head()
# Out:
# Year  Population  Total     Violent  Property  Murder  Forcible_Rape  Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 1960  179323175   3384200   288460   3095700   9110    17190          107840   154320              912100    1855400        328200           1
# 2001  285317559   11876669  1439480  10437480  16037   90863          423557   909023              2116531   7092267        1228391          1
# 1990  248709873   14475600  1820130  12655500  23440   102560         639270   1054860             3073900   7945700        1635900          1
# 1991  252177000   14872900  1911770  12961100  24700   106590         687730   1092740             3157200   8142200        1661700          1
# 1992  255082000   14438200  1932270  12505900  23760   109060         672480   1126970             2979900   7915200        1610800          1
# dtype: int64

# %%
crimes.set_index("Year").head()
# Out:
#       Population    Total  Violent  Property  Murder  Forcible_Rape  Robbery  \
# Year
# 1960   179323175  3384200   288460   3095700    9110          17190   107840
# 1961   182992000  3488000   289390   3198600    8740          17220   106670
# 1962   185771000  3752200   301510   3450700    8530          17550   110860
# 1963   188483000  4109500   316970   3792500    8640          17650   116470
# 1964   191141000  4564600   364220   4200400    9360          21420   130390
#
#       Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# Year
# 1960              154320    912100        1855400         328200
# 1961              156760    949600        1913000         336000
# 1962              164570    994300        2089600         366800
# 1963              174210   1086400        2297800         408300
# 1964              203050   1213200        2514400         472800

# %%
status = crimes[["Population","Total","Property","Murder"]]
status.head()
# Out:
#    Population    Total  Property  Murder
# 0   179323175  3384200   3095700    9110
# 1   182992000  3488000   3198600    8740
# 2   185771000  3752200   3450700    8530
# 3   188483000  4109500   3792500    8640
# 4   191141000  4564600   4200400    9360

# %%
crimes.columns
# Out:
# Index(['Year', 'Population', 'Total', 'Violent', 'Property', 'Murder',
#        'Forcible_Rape', 'Robbery', 'Aggravated_assault', 'Burglary',
#        'Larceny_Theft', 'Vehicle_Theft'],
#       dtype='object')

# %%
crimes.shape
# Out:
# (55, 12)

# %%
print('Number of years :', len(pd.unique(crimes.Year)))
# Out:
# Number of years : 55

# %%
crimes.iloc[:,2:5].head()
# Out:
#      Total  Violent  Property
# 0  3384200   288460   3095700
# 1  3488000   289390   3198600
# 2  3752200   301510   3450700
# 3  4109500   316970   3792500
# 4  4564600   364220   4200400

# %%
crimes.iloc[:,:-2].tail()
# Out:
#     Year  Population     Total  Violent  Property  Murder  Forcible_Rape  \
# 50  2010   309330219  10363873  1251248   9112625   14772          85593
# 51  2011   311587816  10258774  1206031   9052743   14661          84175
# 52  2012   313873685  10219059  1217067   9001992   14866          85141
# 53  2013   316497531   9850445  1199684   8650761   14319          82109
# 54  2014   318857056   9475816  1197987   8277829   14249          84041
#
#     Robbery  Aggravated_assault  Burglary
# 50   369089              781844   2168457
# 51   354772              752423   2185140
# 52   355051              762009   2109932
# 53   345095              726575   1931835
# 54   325802              741291   1729806

# %%
crimes.loc[crimes.Population.isin([309330219, 311587816, 313873685])]
# Out:
#     Year  Population     Total  Violent  Property  Murder  Forcible_Rape  \
# 50  2010   309330219  10363873  1251248   9112625   14772          85593
# 51  2011   311587816  10258774  1206031   9052743   14661          84175
# 52  2012   313873685  10219059  1217067   9001992   14866          85141
#
#     Robbery  Aggravated_assault  Burglary  Larceny_Theft  Vehicle_Theft
# 50   369089              781844   2168457        6204601         739565
# 51   354772              752423   2185140        6151095         716508
# 52   355051              762009   2109932        6168874         723186

# %%
drinks = pd.read_csv("drinks.csv")
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
#Which continent drinks more beer on average?
drinks.groupby(["beer_servings","continent"]).mean()
# Out:
#                          spirit_servings  wine_servings  \
# beer_servings continent
# 0             AF                   0.000            0.0
#               AS                   0.625            0.0
#               EU                   0.000            0.0
#               OC                 127.000           37.0
# 1             AF                   3.000            1.0
# ...                                  ...            ...
# 343           EU                 229.500           56.0
# 346           EU                 117.000          175.0
# 347           AF                  98.000           59.0
# 361           EU                 170.000          134.0
# 376           AF                   3.000            1.0
#
#                          total_litres_of_pure_alcohol
# beer_servings continent
# 0             AF                               0.0000
#               AS                               0.0125
#               EU                               0.0000
#               OC                               2.9500
# 1             AF                               0.1000
# ...                                               ...
# 343           EU                              11.9000
# 346           EU                              11.3000
# 347           AF                               8.9000
# 361           EU                              11.8000
# 376           AF                               6.8000
#
# [138 rows x 3 columns]

# %%
# For each continent print the statistics for wine consumption.
drinks.groupby("continent").describe()
# Out:
#           beer_servings                                                      \
#                   count        mean        std   min     25%    50%     75%
# continent
# AF                 53.0   61.471698  80.557816   0.0   15.00   32.0   76.00
# AS                 44.0   37.045455  49.469725   0.0    4.25   17.5   60.50
# EU                 45.0  193.777778  99.631569   0.0  127.00  219.0  270.00
# OC                 16.0   89.687500  96.641412   0.0   21.00   52.5  125.75
# SA                 12.0  175.083333  65.242845  93.0  129.50  162.5  198.00
#
#                  spirit_servings              ... wine_servings         \
#              max           count        mean  ...           75%    max
# continent                                     ...
# AF         376.0            53.0   16.339623  ...         13.00  233.0
# AS         247.0            44.0   60.840909  ...          8.00  123.0
# EU         361.0            45.0  132.555556  ...        195.00  370.0
# OC         306.0            16.0   58.437500  ...         23.25  212.0
# SA         333.0            12.0  114.750000  ...         98.50  221.0
#
#           total_litres_of_pure_alcohol                                        \
#                                  count      mean       std  min   25%    50%
# continent
# AF                                53.0  3.007547  2.647557  0.0  0.70   2.30
# AS                                44.0  2.170455  2.770239  0.0  0.10   1.20
# EU                                45.0  8.617778  3.358455  0.0  6.60  10.00
# OC                                16.0  3.381250  3.345688  0.0  1.00   1.75
# SA                                12.0  6.308333  1.531166  3.8  5.25   6.85
#
#
#               75%   max
# continent
# AF          4.700   9.1
# AS          2.425  11.5
# EU         10.900  14.4
# OC          6.150  10.4
# SA          7.375   8.3
#
# [5 rows x 32 columns]

# %%
#Print the mean alcohol consumption per continent for every column
drinks.groupby(["beer_servings","wine_servings","spirit_servings","continent"]).mean()
# Out:
#                                                        total_litres_of_pure_alcohol
# beer_servings wine_servings spirit_servings continent
# 0             0             0               AF                                  0.0
#                                             AS                                  0.0
#                                             EU                                  0.0
#                                             OC                                  0.0
#                             5               AS                                  0.1
# ...                                                                             ...
# 343           56            244             EU                                 12.9
# 346           175           117             EU                                 11.3
# 347           59            98              AF                                  8.9
# 361           134           170             EU                                 11.8
# 376           1             3               AF                                  6.8
#
# [160 rows x 1 columns]

# %%
# Print the mean, min and max values for spirit consumption
drinks.groupby("spirit_servings").mean()
drinks.groupby("spirit_servings").min()
drinks.groupby("spirit_servings").max()
# Out:
# <ipython-input-18-0670795b95fc>:3: FutureWarning: Dropping invalid columns in DataFrameGroupBy.min is deprecated. In a future version, a TypeError will be raised. Before calling .min, select only columns which should be valid for the function.
#   drinks.groupby("spirit_servings").min()
# <ipython-input-18-0670795b95fc>:4: FutureWarning: Dropping invalid columns in DataFrameGroupBy.max is deprecated. In a future version, a TypeError will be raised. Before calling .max, select only columns which should be valid for the function.
#   drinks.groupby("spirit_servings").max()
#                             country  beer_servings  wine_servings  \
# spirit_servings
# 0                             Yemen             92            233
# 1                       Timor-Leste            147              9
# 2                           Vietnam            111             19
# 3                           Tunisia            376             20
# 4                          Malaysia             34             13
# ...                             ...            ...            ...
# 302                          Guyana             93              1
# 315                       St. Lucia            171             71
# 326              Russian Federation            247             73
# 373                         Belarus            142             42
# 438                         Grenada            199             28
#
#                  total_litres_of_pure_alcohol
# spirit_servings
# 0                                         6.3
# 1                                         5.8
# 2                                         6.8
# 3                                         6.8
# 4                                         1.1
# ...                                       ...
# 302                                       7.1
# 315                                      10.1
# 326                                      11.5
# 373                                      14.4
# 438                                      11.9
#
# [109 rows x 4 columns]

# %%
drinks.columns
# Out:
# Index(['country', 'beer_servings', 'spirit_servings', 'wine_servings',
#        'total_litres_of_pure_alcohol', 'continent'],
#       dtype='object')

# %%
drinks[["country","beer_servings",'spirit_servings']].value_counts()
# Out:
# country        beer_servings  spirit_servings
# Afghanistan    0              0                  1
# Lithuania      343            244                1
# Nicaragua      78             118                1
# Niger          3              2                  1
# Nigeria        42             5                  1
#                                                 ..
# Grenada        199            438                1
# Guatemala      53             69                 1
# Guinea         9              0                  1
# Guinea-Bissau  28             31                 1
# Zimbabwe       64             18                 1
# Length: 193, dtype: int64

# %%
drinks.sort_values(["country","beer_servings","spirit_servings"]).head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
drinks.sort_values(["country","beer_servings","spirit_servings"], ascending = False).head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 192   Zimbabwe             64               18              4
# 191     Zambia             32               19              4
# 190      Yemen              6                0              0
# 189    Vietnam            111                2              1
# 188  Venezuela            333              100              3
#
#      total_litres_of_pure_alcohol continent
# 192                           4.7        AF
# 191                           2.5        AF
# 190                           0.1        AS
# 189                           2.0        AS
# 188                           7.7        SA

# %%
drinks.iloc[1:4,1:2]
# Out:
#    beer_servings
# 1             89
# 2             25
# 3            245

# %%
drinks.loc[0:3]
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU

# %%
#Matplotlib
b=crimes.groupby(['Population'])[['Property','Murder']].mean().head().plot(kind="bar", figsize=(12,12))
b
# Out:
# <AxesSubplot:xlabel='Population'>

# %%
fig, ax = plt.subplots(figsize=(8, 5))
ax.plot(drinks.beer_servings, label='beer')  # Plot some data on the axes.
ax.plot(drinks.wine_servings, label='wine')  # Plot more data on the axes...
ax.plot(drinks.spirit_servings, label='spirits')  
ax.set_xlabel('x label')  # Add an x-label to the axes.
ax.set_ylabel('y label')  # Add a y-label to the axes.
ax.set_title("alchohol")  # Add a title to the axes.
plt.xticks(rotation=90)
plt.grid()
ax.legend();  # Add a legend.

# %%
plt.scatter(drinks['beer_servings'],drinks['wine_servings'], s=25, marker= 'd', facecolor='red', edgecolor='green')

# %%
plt.boxplot(drinks[['beer_servings', 'spirit_servings']]);

# %%
fig=plt.subplots(2,2)     # figsize=(13,8))
plt.subplot(221,ylabel="y_axis")
plt.plot(drinks['beer_servings'].value_counts().sort_index())
plt.title("Line")
plt.subplot(223,)
plt.scatter(drinks['wine_servings'],drinks.wine_servings,s=2,c="#4734cc")
#plt.autoscale()
plt.title("Scatter plot")
# Out:
# Text(0.5, 1.0, 'Scatter plot')

# %%
#Seaborn
sns.scatterplot(drinks['beer_servings'], drinks['spirit_servings'])
import warnings
warnings.filterwarnings('ignore')

# %%
sns.heatmap(drinks.corr(), annot=True).set_title('Seaborn')
# Out:
# Text(0.5, 1.0, 'Seaborn')

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
drinks.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0        AS
# 1                           4.9        EU
# 2                           0.7        AF
# 3                          12.4        EU
# 4                           5.9        AF

# %%
x= drinks.iloc[:,1:4].values
y = drinks.iloc[:, 4].values
x.shape
y.shape
# Out:
# (193,)

# %%
reg = LinearRegression()
reg = reg.fit(x,y)
y_pred = reg.predict(x)
r2_score= reg.score(x, y)
print('Rsquare :', r2_score)
print('Slope : ', reg.coef_)
print('y_intercept :', reg.intercept_)
# Out:
# Rsquare : 0.8741728224192638
# Slope :  [0.01830291 0.01555814 0.01600524]
# y_intercept : 0.7224498487088482

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x, y ,test_size=0.25,random_state=1)

# %%
print('x_train.shape:', x_train.shape , '\ny_train.shape: ', y_train.shape, '\nx_test.shape: ', x_test.shape , '\ny_test.shape: ', y_test.shape)
# Out:
# x_train.shape: (144, 3)
# y_train.shape:  (144,)
# x_test.shape:  (49, 3)
# y_test.shape:  (49,)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
sc.fit(x_train)
x_scaled_train=sc.transform(x_train)
x_scaled_test=sc.transform(x_test)

# %%
lr_model=LinearRegression()
lr_model.fit(x_scaled_train,y_train)
print(f"Training score ---> {lr_model.score(x_scaled_train,y_train)}")
predict_y =lr_model.predict(x_scaled_test)
print(f"Testing score --->  {lr_model.score(x_scaled_test,y_test)}")
# Out:
# Training score ---> 0.9141401907611192
# Testing score --->  0.7007183359819242

# %%
df = pd.DataFrame(data= {'Actual_price': y_test.flatten(), 'Predict_price': predict_y.flatten()})
df["residual"]=df["Actual_price"]-df["Predict_price"]
df.head()
# Out:
#    Actual_price  Predict_price  residual
# 0           8.2       8.473345 -0.273345
# 1           2.2       2.670899 -0.470899
# 2           1.7       0.881264  0.818736
# 3           7.6       7.852829 -0.252829
# 4           5.7       1.279025  4.420975

# %%
from sklearn.model_selection import KFold, cross_validate, cross_val_score 
scores = cross_validate(lr_model, x_scaled_train, y_train, cv=8)
print(scores.keys())
print('___________________________________________________')
print(scores)
# Out:
# dict_keys(['fit_time', 'score_time', 'test_score'])
# ___________________________________________________
# {'fit_time': array([0.00270724, 0.00264764, 0.00241923, 0.00227475, 0.00200462,
#        0.00211215, 0.0029583 , 0.00218701]), 'score_time': array([0.001158  , 0.00111198, 0.00086856, 0.00104547, 0.00088859,
#        0.0010159 , 0.00086498, 0.00084329]), 'test_score': array([0.97908329, 0.80878024, 0.97935111, 0.96066618, 0.83371287,
#        0.88083817, 0.86398903, 0.98169705])}

# %%
from sklearn.linear_model import Ridge
R_model = Ridge(alpha=1.0).fit(x_scaled_train, y_train)

print(f"Training score ---> {R_model.score(x_scaled_train,y_train)}")
predict_y =R_model.predict(x_scaled_test)
print(f"Testing score --->  {R_model.score(x_scaled_test,y_test)}")

df_1 = pd.DataFrame(data= {'Actual_price': y_test.flatten(), 'Predict_price': predict_y.flatten(), 'residual': df["Actual_price"]-df["Predict_price"]})
df_1.head()
# Out:
# Training score ---> 0.9141259303920171
# Testing score --->  0.701846691278458
#    Actual_price  Predict_price  residual
# 0           8.2       8.459146 -0.273345
# 1           2.2       2.679240 -0.470899
# 2           1.7       0.897061  0.818736
# 3           7.6       7.841449 -0.252829
# 4           5.7       1.293470  4.420975

# %%
from sklearn.model_selection import cross_validate, cross_val_score 
scores = cross_validate(R_model, x_scaled_train, y_train, cv=8)
print(scores.keys())
print('___________________________________________________')
print(scores)
# Out:
# dict_keys(['fit_time', 'score_time', 'test_score'])
# ___________________________________________________
# {'fit_time': array([0.0020628 , 0.00160813, 0.00228286, 0.00170016, 0.00079679,
#        0.00091243, 0.00082779, 0.00083137]), 'score_time': array([0.00085449, 0.001297  , 0.00102234, 0.00060439, 0.00050926,
#        0.00049925, 0.00052857, 0.00079775]), 'test_score': array([0.97865466, 0.80921284, 0.97862557, 0.96083068, 0.83472201,
#        0.88009694, 0.86470559, 0.981907  ])}

# %%
from sklearn.linear_model import Lasso

l_model = Lasso(alpha=1.0).fit(x_scaled_train, y_train)

print(f"Training score ---> {l_model.score(x_scaled_train,y_train)}")
predict_y =l_model.predict(x_scaled_test)
print(f"Testing score --->  {l_model.score(x_scaled_test,y_test)}")

df = pd.DataFrame(data= {'Actual_price': y_test.flatten(), 'Predict_price': predict_y.flatten(), 'residual': df["Actual_price"]-df["Predict_price"]})
df.head()
# Out:
# Training score ---> 0.7956194364465181
# Testing score --->  0.684336384801199
#    Actual_price  Predict_price  residual
# 0           8.2       7.169237 -0.273345
# 1           2.2       3.434905 -0.470899
# 2           1.7       2.237599  0.818736
# 3           7.6       6.397888 -0.252829
# 4           5.7       2.618422  4.420975

# %%
from sklearn.model_selection import cross_validate, cross_val_score 
scores = cross_validate(l_model, x_scaled_train, y_train, cv=8)
print(scores.keys())
print('___________________________________________________')
print(scores)
# Out:
# dict_keys(['fit_time', 'score_time', 'test_score'])
# ___________________________________________________
# {'fit_time': array([0.00237703, 0.00126028, 0.00088263, 0.00183916, 0.00077319,
#        0.00079226, 0.00125885, 0.00125742]), 'score_time': array([0.00111985, 0.00053453, 0.00102019, 0.00061989, 0.00051284,
#        0.0005002 , 0.00089073, 0.00087142]), 'test_score': array([0.84174038, 0.73277685, 0.80802968, 0.82054202, 0.8052448 ,
#        0.69028639, 0.71035358, 0.85804518])}

# %%
from sklearn.linear_model import ElasticNet
elastic = ElasticNet(alpha=1, l1_ratio=0.5, max_iter=100)
elastic.fit(x_scaled_train, y_train)
print('y_incercept: ', elastic.intercept_, '\nSlope: ', elastic.coef_)
print(f"\nTraining score ---> {elastic.score(x_scaled_train,y_train)}")
predict_y =elastic.predict(x_scaled_test)
print(f"Testing score --->  {elastic.score(x_scaled_test,y_test)}")

df = pd.DataFrame(data= {'Actual_price': y_test.flatten(), 'Predict_price': predict_y.flatten(), 'residual': df["Actual_price"]-df["Predict_price"]})
df.head()
# Out:
# y_incercept:  4.873611111111111
# Slope:  [1.27626253 0.95160443 0.85073281]
#
# Training score ---> 0.7969948076130322
# Testing score --->  0.6763036907345563
#    Actual_price  Predict_price  residual
# 0           8.2       7.177121  1.030763
# 1           2.2       3.446490 -1.234905
# 2           1.7       2.302240 -0.537599
# 3           7.6       6.715801  1.202112
# 4           5.7       2.589119  3.081578
